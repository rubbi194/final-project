# %% [markdown]
# Generate comparison from different models

# %%
import os
import cv2
import yaml
import numpy as np
from ultralytics import YOLO
from huggingface_hub import hf_hub_download

# ==========================================================
# 1) LIST OF MODELS (UP TO 5 MODELS)
# ==========================================================
models = [
    {
        "name": "YOLOv8n-S3",
        "repo": "rubbi194/trashdetection",
        "file": "scenario3/yolov8n/best.pt"
    },
    {
        "name": "YOLOv8s-S3",
        "repo": "rubbi194/trashdetection",
        "file": "scenario3/yolov8s/best.pt"
    },
    {
        "name": "YOLOv8m-S3",
        "repo": "rubbi194/trashdetection",
        "file": "scenario3/yolov8m/best.pt"
    },
    {
        "name": "YOLOv8l-S3",
        "repo": "rubbi194/trashdetection",
        "file": "scenario3/yolov8l/best.pt"
    },
    {
        "name": "YOLOv8x-S3",
        "repo": "rubbi194/trashdetection",
        "file": "scenario3/yolov8x/best.pt"
    },
]

# ==========================================================
# 2) Your fixed test images & labels path
# ==========================================================

test_images_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images"
labels_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\labels"

os.makedirs("comparison_multi", exist_ok=True)

# ==========================================================
# Helper – draw YOLO boxes with internal label banner
# ==========================================================
def draw_boxes(img, boxes, color, label_name):
    H, W = img.shape[:2]

    # ========= Draw top banner =========
    banner_h = 50
    overlay = img.copy()
    cv2.rectangle(overlay, (0, 0), (W, banner_h), (0, 0, 0), -1)
    img = cv2.addWeighted(overlay, 0.4, img, 0.6, 0)

    cv2.putText(
        img, label_name, (10, 35),
        cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 255), 3, cv2.LINE_AA
    )

    # ========= Draw bounding boxes =========
    for b in boxes:
        cls, xc, yc, w, h = b

        x1 = int((xc - w/2) * W)
        y1 = int((yc - h/2) * H)
        x2 = int((xc + w/2) * W)
        y2 = int((yc + h/2) * H)

        cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
        cv2.putText(
            img, str(cls), (x1, max(0, y1 - 5)),
            cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2
        )

    return img

# ==========================================================
# Load all models
# ==========================================================
loaded_models = []

for m in models:
    print("Loading:", m["name"])
    model_path = hf_hub_download(
        repo_id=m["repo"],
        filename=m["file"],
        repo_type="model"
    )
    loaded_models.append((m["name"], YOLO(model_path)))

# ==========================================================
# 3) Process entire test set
# ==========================================================
image_exts = [".jpg", ".png", ".jpeg"]

for fname in os.listdir(test_images_dir):
    if not any(fname.lower().endswith(ext) for ext in image_exts):
        continue

    name = os.path.splitext(fname)[0]
    img_path = os.path.join(test_images_dir, fname)

    img = cv2.imread(img_path)
    if img is None:
        print("Cannot load:", img_path)
        continue

    # ------------------------------------------------------
    # Ground truth
    # ------------------------------------------------------
    label_file = os.path.join(labels_dir, name + ".txt")
    gt_boxes_raw = []

    if os.path.exists(label_file):
        with open(label_file, "r") as f:
            for line in f.readlines():
                gt_boxes_raw.append(list(map(float, line.split())))

    gt_boxes = [(b[0], b[1], b[2], b[3], b[4]) for b in gt_boxes_raw]

    gt_img = img.copy()
    gt_img = draw_boxes(gt_img, gt_boxes, (0, 255, 0), "GROUND TRUTH")

    panels = [gt_img]

    # ------------------------------------------------------
    # Predictions for each model
    # ------------------------------------------------------
    for (model_name, model) in loaded_models:
        pred = model(img_path)[0]

        pred_boxes = []
        for r in pred.boxes:
            cls = int(r.cls)
            xc, yc, w, h = r.xywhn[0]
            pred_boxes.append((cls, xc, yc, w, h))

        model_img = img.copy()
        model_img = draw_boxes(
            model_img,
            pred_boxes,
            (0, 0, 255),
            f"PREDICTION – {model_name}"
        )

        panels.append(model_img)

    # ------------------------------------------------------
    # Combine horizontally
    # ------------------------------------------------------
    heights = [p.shape[0] for p in panels]
    max_h = max(heights)

    resized_panels = [
        cv2.resize(p, (p.shape[1], max_h)) for p in panels
    ]

    combined = np.hstack(resized_panels)

    out_path = f"comparison_multi/{name}_multi_compare.jpg"
    cv2.imwrite(out_path, combined)
    print("Saved:", out_path)

print("\n✔ DONE — saved to comparison_multi/")
# Out:
# Loading: YOLOv8n-S3
# Loading: YOLOv8s-S3
# Loading: YOLOv8m-S3
# Loading: YOLOv8l-S3
# Loading: YOLOv8x-S3
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 4 trashs, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 6 trashs, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 29.0ms
# Speed: 1.0ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000101_jpg.rf.fbf75c64095342160f45a3f55d72e725_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 42.0ms
# Speed: 3.0ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 5 trashs, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 4 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 3 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 5 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 3 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 3 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 2 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 4 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 4 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000225_jpg.rf.575306df948e526b06b9deff32c83059_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 2 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000256_jpg.rf.7197fb29a83207067d298d6031dc4d75_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 6 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 4 trashs, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 (no detections), 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 39.0ms
# Speed: 2.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 2 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 (no detections), 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 (no detections), 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 2 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 2 trashs, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 (no detections), 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 3 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 3 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000540_jpg.rf.762e4e86c895ba843747e20b6fc23345_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 (no detections), 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000576_jpg.rf.060a10bce6082a699235640e87da0174_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 2 trashs, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 1 trash, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 3 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 2 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000634_jpg.rf.d871a3ec3983367fa6778195c8250489_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 1 trash, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 2 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 2 trashs, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 2 trashs, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000703_jpg.rf.d65d131b73063d4422d327439bc1307e_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 3 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 4 trashs, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 4 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 3 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 3 trashs, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000976_jpg.rf.6b95ae0567e3900153cd9067b377d044_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 3 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 2 trashs, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 4 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 2 trashs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 3 trashs, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 5 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 3 trashs, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 5 trashs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 2 trashs, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/001014_jpg.rf.100438206cb025644fb2b4a260661713_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 17.0ms
# Speed: 0.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/001056_jpg.rf.582c750d50c34020f112512569261032_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
# Saved: comparison_multi/001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 16.0ms
# ...
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2330_jpg.rf.60b017fce164142dead412891dd997fc.jpg: 192x320 1 trash, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2330_jpg.rf.60b017fce164142dead412891dd997fc_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 2 trashs, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 22.0ms
# Speed: 1.0ms preprocess, 22.0ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 2 trashs, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 4 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 1 trash, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 1 trash, 37.0ms
# Speed: 1.0ms preprocess, 37.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 2 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 33.0ms
# Speed: 1.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 33.0ms
# Speed: 2.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 2 trashs, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 2 trashs, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 (no detections), 33.0ms
# Speed: 0.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 1 trash, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 1 trash, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 1 trash, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 (no detections), 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 26.0ms
# Speed: 2.0ms preprocess, 26.0ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 5 trashs, 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b_multi_compare.jpg
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 1 trash, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 1 trash, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 1 trash, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 2 trashs, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\images\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 2 trashs, 39.0ms
# Speed: 1.0ms preprocess, 39.0ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
# Saved: comparison_multi/scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d_multi_compare.jpg
#
# ✔ DONE — saved to comparison_multi/

# %%
import cv2
import os
import numpy as np

folder = r"C:\Users\User\Documents\Rabab\dataset\Scenario 1\My-First-Project-6"

resolutions = []
blur_scores = []
brightness_scores = []

# Allowed image extensions
valid_ext = ('.jpg', '.jpeg', '.png', '.bmp')

for root, dirs, files in os.walk(folder):
    for img_name in files:
        if img_name.lower().endswith(valid_ext):
            path = os.path.join(root, img_name)
            
            img = cv2.imread(path)
            if img is None:
                continue
            
            # Resolution
            h, w, _ = img.shape
            resolutions.append((w, h))

            # Blur
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            blur_score = cv2.Laplacian(gray, cv2.CV_64F).var()
            blur_scores.append(blur_score)

            # Brightness
            brightness = np.mean(gray)
            brightness_scores.append(brightness)

print("===== RESULTS =====")
print("Total Images:", len(resolutions))

if len(resolutions) > 0:
    print("Min Resolution:", min(resolutions))
    print("Max Resolution:", max(resolutions))
    print(
        "Average Resolution (Width x Height):",
        np.mean([r[0] for r in resolutions]),
        "x",
        np.mean([r[1] for r in resolutions])
    )
else:
    print("No images found.")

# Thresholds (you can keep these as default)
blur_threshold = 100         # <100 = blurry
brightness_threshold = 80    # <80 = low-light

print("Blurry Images:", sum(b < blur_threshold for b in blur_scores))
print("Low-Light Images:", sum(b < brightness_threshold for b in brightness_scores))
# Out:
# ===== RESULTS =====
# Total Images: 10028
# Min Resolution: (640, 640)
# Max Resolution: (640, 640)
# Average Resolution (Width x Height): 640.0 x 640.0
# Blurry Images: 4
# Low-Light Images: 0

# %%
import cv2
import os
import numpy as np

folder = r"C:\Users\User\Documents\Rabab\dataset\Scenario 2\My-First-Project-8"

resolutions = []
blur_scores = []
brightness_scores = []

# Allowed image extensions
valid_ext = ('.jpg', '.jpeg', '.png', '.bmp')

for root, dirs, files in os.walk(folder):
    for img_name in files:
        if img_name.lower().endswith(valid_ext):
            path = os.path.join(root, img_name)
            
            img = cv2.imread(path)
            if img is None:
                continue
            
            # Resolution
            h, w, _ = img.shape
            resolutions.append((w, h))

            # Blur
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            blur_score = cv2.Laplacian(gray, cv2.CV_64F).var()
            blur_scores.append(blur_score)

            # Brightness
            brightness = np.mean(gray)
            brightness_scores.append(brightness)

print("===== SCENARIO 2 RESULTS =====")
print("Total Images:", len(resolutions))

if len(resolutions) > 0:
    print("Min Resolution:", min(resolutions))
    print("Max Resolution:", max(resolutions))
    print(
        "Average Resolution (Width x Height):",
        np.mean([r[0] for r in resolutions]),
        "x",
        np.mean([r[1] for r in resolutions])
    )
else:
    print("No images found.")

# Thresholds (default)
blur_threshold = 100
brightness_threshold = 80

print("Blurry Images:", sum(b < blur_threshold for b in blur_scores))
print("Low-Light Images:", sum(b < brightness_threshold for b in brightness_scores))
# Out:
# ===== SCENARIO 2 RESULTS =====
# Total Images: 25433
# Min Resolution: (640, 640)
# Max Resolution: (640, 640)
# Average Resolution (Width x Height): 640.0 x 640.0
# Blurry Images: 397
# Low-Light Images: 937

# %%
import cv2
import os
import numpy as np

folder = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\My-First-Project-11"

resolutions = []
blur_scores = []
brightness_scores = []

# Allowed image extensions
valid_ext = ('.jpg', '.jpeg', '.png', '.bmp')

for root, dirs, files in os.walk(folder):
    for img_name in files:
        if img_name.lower().endswith(valid_ext):
            path = os.path.join(root, img_name)
            
            img = cv2.imread(path)
            if img is None:
                continue
            
            # Resolution
            h, w, _ = img.shape
            resolutions.append((w, h))

            # Blur detection
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            blur_score = cv2.Laplacian(gray, cv2.CV_64F).var()
            blur_scores.append(blur_score)

            # Brightness detection
            brightness = np.mean(gray)
            brightness_scores.append(brightness)

print("===== SCENARIO 3 RESULTS =====")
print("Total Images:", len(resolutions))

if len(resolutions) > 0:
    print("Min Resolution:", min(resolutions))
    print("Max Resolution:", max(resolutions))
    print(
        "Average Resolution (Width x Height):",
        np.mean([r[0] for r in resolutions]),
        "x",
        np.mean([r[1] for r in resolutions])
    )
else:
    print("No images found.")

# Thresholds
blur_threshold = 100         # <100 = blurry
brightness_threshold = 80    # <80 = low-light

print("Blurry Images:", sum(b < blur_threshold for b in blur_scores))
print("Low-Light Images:", sum(b < brightness_threshold for b in brightness_scores))
# Out:
# ===== SCENARIO 3 RESULTS =====
# Total Images: 25433
# Min Resolution: (572, 572)
# Max Resolution: (2048, 1365)
# Average Resolution (Width x Height): 1773.472968190933 x 1041.514764282625
# Blurry Images: 19359
# Low-Light Images: 2424

# %%
import os
import glob
import shutil
import numpy as np
from ultralytics import YOLO

# ==========================
# 1. CONFIGURATION
# ==========================

# Folder with test images (Scenario 1, your test set)
IMG_DIR = r"C:\Users\User\Documents\Rabab\dataset\Scenario 1\My-First-Project-6\test\images"
LABEL_DIR = r"C:\Users\User\Documents\Rabab\dataset\Scenario 1\My-First-Project-6\test\labels"

# Output folders (will be created if not exist)
OUT_ROOT = r"C:\Users\User\Documents\Rabab\dataset\Scenario 1\analysis_detection"
SUCCESS_DIR = os.path.join(OUT_ROOT, "success_detection")
PARTIAL_DIR = os.path.join(OUT_ROOT, "partial_detection")
MISSED_DIR = os.path.join(OUT_ROOT, "missed_detection")

os.makedirs(SUCCESS_DIR, exist_ok=True)
os.makedirs(PARTIAL_DIR, exist_ok=True)
os.makedirs(MISSED_DIR, exist_ok=True)

# Base directory where your YOLO runs & models live
BASE_MODEL_DIR = r"C:\Users\User\Documents\Rabab"

# IoU thresholds
IOU_SUCCESS = 0.5   # good detection
IOU_PARTIAL = 0.1   # weak detection, but some overlap


# ==========================
# 2. Find best.pt automatically
# ==========================

def find_best_weight(base_dir, keywords=("scenario1", "yolov8l")):
    """
    Search recursively for 'best.pt' under base_dir.
    Prefer paths that contain all given keywords.
    """
    candidates = []
    for root, dirs, files in os.walk(base_dir):
        for f in files:
            if f.lower() == "best.pt":
                full_path = os.path.join(root, f)
                candidates.append(full_path)

    if not candidates:
        raise FileNotFoundError(f"No best.pt found under {base_dir}")

    # Try to pick the one that matches all keywords
    keywords = [k.lower() for k in keywords]
    for path in candidates:
        low = path.lower()
        if all(k in low for k in keywords):
            print(f"[INFO] Using weight (matched keywords): {path}")
            return path

    # Fallback: just use the first best.pt found
    print("[WARN] No best.pt matched all keywords; using first found:")
    print("       ", candidates[0])
    return candidates[0]


MODEL_PATH = find_best_weight(BASE_MODEL_DIR, keywords=("scenario1", "yolov8l"))
model = YOLO(MODEL_PATH)


# ==========================
# 3. Helper functions
# ==========================

def xywhn_to_xyxy(box, img_w, img_h):
    """
    Convert YOLO normalized [cx, cy, w, h] to pixel [x1, y1, x2, y2].
    """
    cx, cy, w, h = box
    x1 = (cx - w / 2) * img_w
    y1 = (cy - w / 2) * img_h  # fix: y uses h
    y1 = (cy - h / 2) * img_h
    x2 = (cx + w / 2) * img_w
    y2 = (cy + h / 2) * img_h
    return [x1, y1, x2, y2]


def iou(boxA, boxB):
    """
    Compute Intersection over Union (IoU) between two boxes.
    """
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interW = max(0, xB - xA)
    interH = max(0, yB - yA)
    interArea = interW * interH

    if interArea == 0:
        return 0.0

    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])

    return interArea / (boxAArea + boxBArea - interArea)


# ==========================
# 4. Main loop over images
# ==========================

image_paths = (
    glob.glob(os.path.join(IMG_DIR, "*.jpg")) +
    glob.glob(os.path.join(IMG_DIR, "*.png")) +
    glob.glob(os.path.join(IMG_DIR, "*.jpeg"))
)

print(f"Total test images found: {len(image_paths)}")

for img_path in image_paths:
    img_name = os.path.basename(img_path)
    name_wo_ext = os.path.splitext(img_name)[0]

    # Ground-truth label path
    label_path = os.path.join(LABEL_DIR, name_wo_ext + ".txt")

    if not os.path.exists(label_path):
        print(f"[WARN] No GT label for {img_name}, skipping.")
        continue

    # ---- 4.1 Read ground-truth YOLO labels ----
    gt_boxes = []
    gt_classes = []

    with open(label_path, "r") as f:
        for line in f.readlines():
            parts = line.strip().split()
            if len(parts) != 5:
                continue
            cls = int(parts[0])
            cx, cy, w, h = map(float, parts[1:])
            gt_classes.append(cls)
            gt_boxes.append([cx, cy, w, h])

    if len(gt_boxes) == 0:
        print(f"[INFO] No GT objects in {img_name}, skipping.")
        continue

    # ---- 4.2 Run YOLO prediction ----
    results = model(img_path, verbose=False)[0]
    img_h, img_w = results.orig_shape

    pred_boxes = []
    pred_classes = []

    for b in results.boxes:
        xyxy = b.xyxy[0].cpu().numpy()
        cls = int(b.cls.cpu().numpy())
        pred_boxes.append(xyxy)
        pred_classes.append(cls)

    # ---- 4.3 Decide category (success / partial / missed) ----
    if len(pred_boxes) == 0:
        category = "missed"
    else:
        best_category = 0  # 0=missed, 1=partial, 2=success

        for gt_box, gt_cls in zip(gt_boxes, gt_classes):
            gt_xyxy = xywhn_to_xyxy(gt_box, img_w, img_h)
            best_iou_for_gt = 0.0

            for pb, pc in zip(pred_boxes, pred_classes):
                if pc != gt_cls:
                    continue
                current_iou = iou(gt_xyxy, pb)
                best_iou_for_gt = max(best_iou_for_gt, current_iou)

            if best_iou_for_gt >= IOU_SUCCESS:
                best_category = max(best_category, 2)
            elif IOU_PARTIAL <= best_iou_for_gt < IOU_SUCCESS:
                best_category = max(best_category, 1)

        category = (
            "success" if best_category == 2 else
            "partial" if best_category == 1 else
            "missed"
        )

    # ---- 4.4 Copy image into the corresponding folder ----
    if category == "success":
        dst_dir = SUCCESS_DIR
    elif category == "partial":
        dst_dir = PARTIAL_DIR
    else:
        dst_dir = MISSED_DIR

    shutil.copy2(img_path, os.path.join(dst_dir, img_name))
    print(f"{img_name}  -->  {category}")
# Out:
# [WARN] No best.pt matched all keywords; using first found:
#         C:\Users\User\Documents\Rabab\Rubi's Project-20251021T100222Z-1-001\Rubi_s Project\yolov8l\finetuning-1\weights\best.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 67
#      63     return candidates[0]
#      66 MODEL_PATH = find_best_weight(BASE_MODEL_DIR, keywords=("scenario1", "yolov8l"))
# ---> 67 model = YOLO(MODEL_PATH)
#      70 # ==========================
#      71 # 3. Helper functions
#      72 # ==========================
#      74 def xywhn_to_xyxy(box, img_w, img_h):
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\engine\model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#     147 # Delete super().training for accessing self.model.training
#     148 del self.training
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\engine\model.py:288, in Model._load(self, weights, task)
#     285 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     287 if Path(weights).suffix == ".pt":
# --> 288     self.model, self.ckpt = attempt_load_one_weight(weights)
#     289     self.task = self.model.args["task"]
#     290     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\nn\tasks.py:910, in attempt_load_one_weight(weight, device, inplace, fuse)
#     908 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     909     """Loads a single model weights."""
# --> 910     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     911     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     912     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\nn\tasks.py:837, in torch_safe_load(weight, safe_only)
#     835                 ckpt = torch.load(f, pickle_module=safe_pickle)
#     836         else:
# --> 837             ckpt = torch.load(file, map_location="cpu")
#     839 except ModuleNotFoundError as e:  # e.name is missing module name
#     840     if e.name == "models":
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\ultralytics\utils\patches.py:86, in torch_load(*args, **kwargs)
#      83 if TORCH_1_13 and "weights_only" not in kwargs:
#      84     kwargs["weights_only"] = False
# ---> 86 return _torch_load(*args, **kwargs)
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1476 if "encoding" not in pickle_load_args.keys():
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#    1484         orig_position = opened_file.tell()
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File c:\Users\User\.conda\envs\ultralytics\lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\Documents\\Rabab\\Rubis Project-20251021T100222Z-1-001\\Rubi_s Project\\yolov8l\\finetuning-1\\weights\\best.pt'
