# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2oeGI3QWbiYo6HNrErIp")
project = rf.workspace("aaaa-g4pgj").project("test-set-m1fru")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8n/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8n on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<00:00, 676.66it/s]
# val: New cache created: C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels.cache
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:01<00:00,  7.10it/s]
#                    all        203        595      0.769      0.496       0.55      0.277
# Speed: 0.1ms preprocess, 3.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs\detect\val26
# YOLOv8n on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.27715806309648683
# MAP 50 0.5501051797589647
# MAP 75 0.22401457281548454
# MAP each category [    0.27716]
# Mean Precision 0.7686081347919076
# Mean Recall 0.4957983193277311
#  [    0.27716]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8s/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8s on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--rubbi194--trashdetection. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  5.74it/s]
#                    all        203        595      0.817      0.521      0.597      0.315
# Speed: 0.1ms preprocess, 4.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val27
# YOLOv8s on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.3148608636122533
# MAP 50 0.597349290516566
# MAP 75 0.29855439893396474
# MAP each category [    0.31486]
# Mean Precision 0.8167394666190811
# Mean Recall 0.5210084033613446
#  [    0.31486]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8m/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8m on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  5.69it/s]
#                    all        203        595      0.832      0.492      0.591       0.32
# Speed: 0.1ms preprocess, 4.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\val28
# YOLOv8m on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.3197181142105955
# MAP 50 0.590916246907161
# MAP 75 0.30284783301529733
# MAP each category [    0.31972]
# Mean Precision 0.8319044789386814
# Mean Recall 0.492436974789916
#  [    0.31972]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8l/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8l on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  5.75it/s]
#                    all        203        595      0.799      0.504      0.588      0.325
# Speed: 0.1ms preprocess, 5.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs\detect\val29
# YOLOv8l on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.3247668348299648
# MAP 50 0.5884407465717295
# MAP 75 0.3226800149233737
# MAP each category [    0.32477]
# Mean Precision 0.7986943929237144
# Mean Recall 0.5042016806722689
#  [    0.32477]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8x/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8x on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test-set-4\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  5.95it/s]
#                    all        203        595      0.806      0.502       0.61      0.349
# Speed: 0.1ms preprocess, 5.5ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs\detect\val31
# YOLOv8x on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.34883088786564576
# MAP 50 0.6104664759862704
# MAP 75 0.38563938430525796
# MAP each category [    0.34883]
# Mean Precision 0.8056597524512225
# Mean Recall 0.5016553272404133
#  [    0.34883]
