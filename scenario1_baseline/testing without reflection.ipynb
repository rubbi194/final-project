# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2oeGI3QWbiYo6HNrErIp")
project = rf.workspace("aaaa-g4pgj").project("test-xkimg")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8n/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8n on Test Set Metrics without Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<00:00, 477.94it/s]
# val: New cache created: C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.12it/s]
#                    all        206        583      0.482      0.214       0.26      0.124
# Speed: 0.3ms preprocess, 3.3ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs\detect\val34
# YOLOv8n on Test Set Metrics without Reflection, scenario 1:
# MAP 50-95 0.12385668697801151
# MAP 50 0.2604249247494224
# MAP 75 0.10109652697323487
# MAP each category [    0.12386]
# Mean Precision 0.48197680346581023
# Mean Recall 0.2144082332761578
#  [    0.12386]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8x/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8x on Test Set Metrics without Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:05<00:00,  2.47it/s]
#                    all        206        583      0.479      0.307      0.304      0.102
# Speed: 0.1ms preprocess, 4.5ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\val37
# YOLOv8x on Test Set Metrics without Reflection, scenario 1:
# MAP 50-95 0.1023087012302835
# MAP 50 0.3039202654756362
# MAP 75 0.04111514898558224
# MAP each category [    0.10231]
# Mean Precision 0.47893838141537287
# Mean Recall 0.307032590051458
#  [    0.10231]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8m/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8m on Test Set Metrics without Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.24it/s]
#                    all        206        583      0.611       0.31      0.343      0.128
# Speed: 0.2ms preprocess, 4.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs\detect\val39
# YOLOv8m on Test Set Metrics without Reflection, scenario 1:
# MAP 50-95 0.12809512525276515
# MAP 50 0.3425616959903852
# MAP 75 0.06467384837481321
# MAP each category [     0.1281]
# Mean Precision 0.61099233472202
# Mean Recall 0.31046312178387653
#  [     0.1281]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8l/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8l on Test Set Metrics without Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:05<00:00,  2.42it/s]
#                    all        206        583      0.481      0.345      0.317      0.109
# Speed: 0.1ms preprocess, 5.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs\detect\val40
# YOLOv8l on Test Set Metrics without Reflection, scenario 1:
# MAP 50-95 0.10914692976520671
# MAP 50 0.3170998107028279
# MAP 75 0.04708306431293386
# MAP each category [    0.10915]
# Mean Precision 0.48057154209274877
# Mean Recall 0.34476843910806176
#  [    0.10915]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario1/yolo8s/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8s on Test Set Metrics without Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario1_baseline\test--2\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:05<00:00,  2.46it/s]
#                    all        206        583      0.503       0.37      0.365      0.132
# Speed: 0.1ms preprocess, 2.9ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs\detect\val41
# YOLOv8s on Test Set Metrics without Reflection, scenario 1:
# MAP 50-95 0.13190325657057553
# MAP 50 0.3648911352417045
# MAP 75 0.06899826931086361
# MAP each category [     0.1319]
# Mean Precision 0.503401389808771
# Mean Recall 0.3704974271012007
#  [     0.1319]
