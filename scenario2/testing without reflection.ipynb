# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2oeGI3QWbiYo6HNrErIp")
project = rf.workspace("aaaa-g4pgj").project("test-xkimg")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8n/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8n on Test Set Metrics without Reflection, scenario 2:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test--3\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:04<00:00,  3.10it/s]
#                    all        206        583      0.762      0.431      0.501       0.25
# Speed: 0.2ms preprocess, 3.1ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs\detect\val18
# YOLOv8n on Test Set Metrics without Reflection, scenario 2:
# MAP 50-95 0.24959742628137352
# MAP 50 0.5006895747622393
# MAP 75 0.21215182317596937
# MAP each category [     0.2496]
# Mean Precision 0.7618543103775287
# Mean Recall 0.4305317324185249
#  [     0.2496]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8x/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8x on Test Set Metrics without Reflection, scenario  2:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test--3\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:06<00:00,  2.15it/s]
#                    all        206        583      0.651       0.54      0.586      0.282
# Speed: 0.1ms preprocess, 5.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val19
# YOLOv8x on Test Set Metrics without Reflection, scenario  2:
# MAP 50-95 0.28184870720181443
# MAP 50 0.5860262268663479
# MAP 75 0.22767639914659776
# MAP each category [    0.28185]
# Mean Precision 0.6508367982366626
# Mean Recall 0.5403334113296273
#  [    0.28185]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8m/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8m on Test Set Metrics without Reflection, scenario 2:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test--3\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:05<00:00,  2.21it/s]
#                    all        206        583      0.693      0.503      0.537      0.245
# Speed: 0.2ms preprocess, 4.1ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs\detect\val20
# YOLOv8m on Test Set Metrics without Reflection, scenario 2:
# MAP 50-95 0.24518803916906187
# MAP 50 0.5373404906677384
# MAP 75 0.18457400951130884
# MAP each category [    0.24519]
# Mean Precision 0.6925971194833276
# Mean Recall 0.5025728987993139
#  [    0.24519]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8l/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8l on Test Set Metrics without Reflection, scenario 2:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test--3\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:06<00:00,  2.16it/s]
#                    all        206        583      0.642      0.537      0.575       0.27
# Speed: 0.1ms preprocess, 5.0ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\val21
# YOLOv8l on Test Set Metrics without Reflection, scenario 2:
# MAP 50-95 0.26963114197944194
# MAP 50 0.5747291162238571
# MAP 75 0.22527845927306592
# MAP each category [    0.26963]
# Mean Precision 0.6417149497991145
# Mean Recall 0.5368782161234992
#  [    0.26963]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8s/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)
metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8s on Test Set Metrics without Reflection, scenario 2:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test--3\test\labels.cache... 206 images, 0 backgrounds, 0 corrupt: 100%|██████████| 206/206 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:06<00:00,  2.09it/s]
#                    all        206        583      0.756      0.455       0.52      0.245
# Speed: 0.1ms preprocess, 3.1ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs\detect\val22
# YOLOv8s on Test Set Metrics without Reflection, scenario 2:
# MAP 50-95 0.24487751874453992
# MAP 50 0.5195047815532037
# MAP 75 0.19327757687365055
# MAP each category [    0.24488]
# Mean Precision 0.7560814343500446
# Mean Recall 0.45454545454545453
#  [    0.24488]
