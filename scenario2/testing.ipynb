# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2oeGI3QWbiYo6HNrErIp")
project = rf.workspace("aaaa-g4pgj").project("test-set-m1fru")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8n/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8n on Test Set Metrics with Reflection, scenario 2")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test-set-5\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:01<00:00,  6.70it/s]
#                    all        203        595      0.846      0.527      0.601      0.299
# Speed: 0.2ms preprocess, 3.4ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs\detect\val11
# YOLOv8n on Test Set Metrics with Reflection, scenario 2
# MAP 50-95 0.2992416512322794
# MAP 50 0.6011564835302714
# MAP 75 0.230744772530827
# MAP each category [    0.29924]
# Mean Precision 0.8460690979997737
# Mean Recall 0.5265488746109078
#  [    0.29924]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8s/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8s on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test-set-5\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  6.27it/s]
#                    all        203        595      0.815      0.525      0.608      0.326
# Speed: 0.1ms preprocess, 3.9ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs\detect\val12
# YOLOv8s on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.3256606553503067
# MAP 50 0.6079240935564242
# MAP 75 0.2984035751246635
# MAP each category [    0.32566]
# Mean Precision 0.8147355989670133
# Mean Recall 0.5247672863362906
#  [    0.32566]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8m/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8m on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 218 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test-set-5\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  6.15it/s]
#                    all        203        595      0.764      0.568      0.627      0.336
# Speed: 0.1ms preprocess, 4.4ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\detect\val13
# YOLOv8m on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.33639060136691873
# MAP 50 0.6265280304431617
# MAP 75 0.3085700468110882
# MAP each category [    0.33639]
# Mean Precision 0.7638146315510077
# Mean Recall 0.5680672268907563
#  [    0.33639]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8l/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8l on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test-set-5\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  6.02it/s]
#                    all        203        595      0.774      0.528        0.6      0.335
# Speed: 0.1ms preprocess, 4.7ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\detect\val14
# YOLOv8l on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.3349062669651895
# MAP 50 0.5998877963176795
# MAP 75 0.3295240223079039
# MAP each category [    0.33491]
# Mean Precision 0.7735979471935048
# Mean Recall 0.5283316037659685
#  [    0.33491]

# %%
from huggingface_hub import hf_hub_download
from ultralytics import YOLO

# Download model weights from HF Hub
model_path = hf_hub_download(repo_id="rubbi194/trashdetection", filename="scenario2/yolo8x/best.pt", repo_type="model")

# Load with YOLO
modeln = YOLO(model_path)

metrics = modeln.val(data=dataset.location+"/data.yaml", split='test')

# Accessing metrics
print("YOLOv8x on Test Set Metrics with Reflection, scenario 1:")
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp) 
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario2\test-set-5\test\labels.cache... 203 images, 0 backgrounds, 0 corrupt: 100%|██████████| 203/203 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 595. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [00:02<00:00,  6.03it/s]
#                    all        203        595      0.762      0.555      0.627      0.357
# Speed: 0.1ms preprocess, 4.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs\detect\val15
# YOLOv8x on Test Set Metrics with Reflection, scenario 1:
# MAP 50-95 0.35693808789340664
# MAP 50 0.6270938162254646
# MAP 75 0.3774903628986578
# MAP each category [    0.35694]
# Mean Precision 0.762381200405834
# Mean Recall 0.5554083371569738
#  [    0.35694]
