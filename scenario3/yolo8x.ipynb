# %%
from ultralytics import YOLO

model = YOLO('yolov8x.pt')  # Load pretrained model (change if using a custom model)

# Train the model
model.train(data="C:/Users/User/Documents/Rabab/repo/final-project/scenario3/My-First-Project-11/data.yaml",
    epochs=100, imgsz=320, batch=16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               , optimizer='AdamW',
    lr0=0.001, lrf=0.01,
    warmup_epochs=3,
    weight_decay=0.01,
    patience=0,
    device=0, workers=0, project="yolov8x", name="finetuning-1", exist_ok=True, amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...

# %%
# Validate the model — dataset and parameters inferred automatically
metrics = model.val(data="C:/Users/User/Documents/Rabab/repo/final-project/scenario3/My-First-Project-11/data.yaml", split='test')

# Accessing metrics
print("MAP 50-95", metrics.box.map)  # map50-95
print("MAP 50", metrics.box.map50)  # map50
print("MAP 75",metrics.box.map75)  # map75
print("MAP each category",metrics.box.maps)  # a list contains map50-95 of each category
print("Mean Precision",metrics.box.mp)
print("Mean Recall",metrics.box.mr)
print("",metrics.box.ap)
# Out:
# Ultralytics 8.3.40  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Model summary (fused): 268 layers, 68,124,531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning C:\Users\User\Documents\Rabab\repo\final-project\scenario3\My-First-Project-11\test\labels.cache... 1608 images, 50 backgrounds, 0 corrupt: 100%|██████████| 1608/1608 [00:00<?, ?it/s]
# WARNING  Box and segment counts should be equal, but got len(segments) = 369, len(boxes) = 5182. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 101/101 [00:40<00:00,  2.49it/s]
#                    all       1608       5182      0.826      0.554      0.653      0.422
# Speed: 0.1ms preprocess, 4.6ms inference, 0.0ms loss, 1.0ms postprocess per image
# ...
