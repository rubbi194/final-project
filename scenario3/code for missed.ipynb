# %%
from ultralytics import YOLO
import cv2
import os
import numpy as np

# ---------------- CONFIG ----------------
model = YOLO("yolov8s.pt")  # or your trained model
img_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed"
label_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\labels"

out_base = "dataset/analysis"
missed_dir = os.path.join(out_base, "missed")
partial_dir = os.path.join(out_base, "partial")
success_dir = os.path.join(out_base, "success")

os.makedirs(missed_dir, exist_ok=True)
os.makedirs(partial_dir, exist_ok=True)
os.makedirs(success_dir, exist_ok=True)

IOU_THRESHOLD = 0.5
# ----------------------------------------

def load_gt_boxes(label_path, img_w, img_h):
    boxes = []
    if not os.path.exists(label_path):
        return boxes

    with open(label_path, "r") as f:
        for line in f:
            cls, x, y, w, h = map(float, line.split())
            x1 = int((x - w / 2) * img_w)
            y1 = int((y - h / 2) * img_h)
            x2 = int((x + w / 2) * img_w)
            y2 = int((y + h / 2) * img_h)
            boxes.append([x1, y1, x2, y2])
    return boxes

def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    inter = max(0, xB - xA) * max(0, yB - yA)
    areaA = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    areaB = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])

    return inter / (areaA + areaB - inter + 1e-6)

# ---------------- PROCESS ----------------
for img_name in os.listdir(img_dir):
    if not img_name.lower().endswith((".jpg", ".png")):
        continue

    img_path = os.path.join(img_dir, img_name)
    label_path = os.path.join(label_dir, img_name.replace(".jpg", ".txt").replace(".png", ".txt"))

    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    gt_boxes = load_gt_boxes(label_path, w, h)

    results = model(img_path, conf=0.25, verbose=False)[0]
    pred_boxes = results.boxes.xyxy.cpu().numpy() if results.boxes else []

    matched_gt = set()

    for p in pred_boxes:
        for i, g in enumerate(gt_boxes):
            if iou(p, g) > IOU_THRESHOLD:
                matched_gt.add(i)

    # -------- CLASSIFICATION --------
    if len(gt_boxes) > 0 and len(matched_gt) == 0:
        out_dir = missed_dir
    elif 0 < len(matched_gt) < len(gt_boxes):
        out_dir = partial_dir
    else:
        out_dir = success_dir

    # draw GT boxes (green)
    for g in gt_boxes:
        cv2.rectangle(img, (g[0], g[1]), (g[2], g[3]), (0, 255, 0), 2)

    # draw predicted boxes (red)
    for p in pred_boxes:
        cv2.rectangle(img, (int(p[0]), int(p[1])), (int(p[2]), int(p[3])), (0, 0, 255), 2)

    cv2.imwrite(os.path.join(out_dir, img_name), img)

print("Analysis images generated successfully.")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 62.6MB/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 51
#      48     return inter / (areaA + areaB - inter + 1e-6)
#      50 # ---------------- PROCESS ----------------
# ---> 51 for img_name in os.listdir(img_dir):
#      52     if not img_name.lower().endswith((".jpg", ".png")):
#      53         continue
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset/images/val'

# %% [markdown]
# Right one

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO
from huggingface_hub import hf_hub_download

# ==========================================================
# 1) MODELS (SCENARIO 3)
# ==========================================================
models = [
    {"name": "YOLOv8n-S3", "repo": "rubbi194/trashdetection", "file": "scenario3/yolov8n/best.pt"},
    {"name": "YOLOv8s-S3", "repo": "rubbi194/trashdetection", "file": "scenario3/yolov8s/best.pt"},
    {"name": "YOLOv8m-S3", "repo": "rubbi194/trashdetection", "file": "scenario3/yolov8m/best.pt"},
    {"name": "YOLOv8l-S3", "repo": "rubbi194/trashdetection", "file": "scenario3/yolov8l/best.pt"},
    {"name": "YOLOv8x-S3", "repo": "rubbi194/trashdetection", "file": "scenario3/yolov8x/best.pt"},
]

# ==========================================================
# 2) DATA PATHS (YOUR PATHS)
# ==========================================================
test_images_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed"
labels_dir = r"C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test\labels"

# ==========================================================
# OUTPUT DIRECTORIES
# ==========================================================
analysis_root = "analysis"
missed_dir = os.path.join(analysis_root, "missed")
partial_dir = os.path.join(analysis_root, "partial")
success_dir = os.path.join(analysis_root, "success")
compare_dir = "comparison_multi"

os.makedirs(missed_dir, exist_ok=True)
os.makedirs(partial_dir, exist_ok=True)
os.makedirs(success_dir, exist_ok=True)
os.makedirs(compare_dir, exist_ok=True)

# ==========================================================
# DRAW BOXES WITH BANNER
# ==========================================================
def draw_boxes(img, boxes, color, label_name):
    H, W = img.shape[:2]

    banner_h = 50
    overlay = img.copy()
    cv2.rectangle(overlay, (0, 0), (W, banner_h), (0, 0, 0), -1)
    img = cv2.addWeighted(overlay, 0.4, img, 0.6, 0)

    cv2.putText(img, label_name, (10, 35),
                cv2.FONT_HERSHEY_SIMPLEX, 1.1, (255, 255, 255), 3)

    for b in boxes:
        cls, xc, yc, w, h = b  # always 5 now

        x1 = int((xc - w / 2) * W)
        y1 = int((yc - h / 2) * H)
        x2 = int((xc + w / 2) * W)
        y2 = int((yc + h / 2) * H)

        cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
        cv2.putText(img, str(int(cls)), (x1, max(0, y1 - 5)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    return img

# ==========================================================
# POLYGON → YOLO BBOX (CRITICAL FIX)
# ==========================================================
def polygon_to_yolo_bbox(poly):
    """
    poly = [cls, x1, y1, x2, y2, ..., xn, yn]
    returns [cls, xc, yc, w, h]
    """
    cls = poly[0]
    coords = poly[1:]

    xs = coords[0::2]
    ys = coords[1::2]

    x_min, x_max = min(xs), max(xs)
    y_min, y_max = min(ys), max(ys)

    xc = (x_min + x_max) / 2
    yc = (y_min + y_max) / 2
    w = x_max - x_min
    h = y_max - y_min

    return [cls, xc, yc, w, h]

# ==========================================================
# IOU HELPERS
# ==========================================================
def yolo_to_xyxy(box, W, H):
    _, xc, yc, w, h = box
    return [
        int((xc - w/2) * W),
        int((yc - h/2) * H),
        int((xc + w/2) * W),
        int((yc + h/2) * H),
    ]

def iou(a, b):
    xA, yA = max(a[0], b[0]), max(a[1], b[1])
    xB, yB = min(a[2], b[2]), min(a[3], b[3])
    inter = max(0, xB-xA) * max(0, yB-yA)
    areaA = (a[2]-a[0]) * (a[3]-a[1])
    areaB = (b[2]-b[0]) * (b[3]-b[1])
    return inter / (areaA + areaB - inter + 1e-6)

# ==========================================================
# LOAD MODELS
# ==========================================================
loaded_models = []
for m in models:
    print("Loading:", m["name"])
    path = hf_hub_download(repo_id=m["repo"], filename=m["file"], repo_type="model")
    loaded_models.append((m["name"], YOLO(path)))

# ==========================================================
# PROCESS DATASET
# ==========================================================
IOU_THRESH = 0.5
image_exts = (".jpg", ".png", ".jpeg")

for fname in os.listdir(test_images_dir):
    if not fname.lower().endswith(image_exts):
        continue

    name = os.path.splitext(fname)[0]
    img_path = os.path.join(test_images_dir, fname)
    img = cv2.imread(img_path)
    if img is None:
        continue

    H, W = img.shape[:2]

    # ---------- LOAD GT (SEGMENTATION SAFE) ----------
    gt_boxes = []
    label_path = os.path.join(labels_dir, name + ".txt")

    if os.path.exists(label_path):
        with open(label_path) as f:
            for line in f:
                values = list(map(float, line.split()))
                if len(values) > 5:   # segmentation polygon
                    gt_boxes.append(polygon_to_yolo_bbox(values))
                else:                 # normal YOLO box
                    gt_boxes.append(values)

    gt_panel = draw_boxes(img.copy(), gt_boxes, (0,255,0), "GROUND TRUTH")
    panels = [gt_panel]

    # ---------- PER MODEL ----------
    for model_name, model in loaded_models:
        pred = model(img_path)[0]

        pred_boxes = []
        for r in pred.boxes:
            cls = int(r.cls)
            xc, yc, w, h = r.xywhn[0]
            pred_boxes.append([cls, xc, yc, w, h])

        gt_xyxy = [yolo_to_xyxy(b, W, H) for b in gt_boxes]
        pred_xyxy = [yolo_to_xyxy(b, W, H) for b in pred_boxes]

        matched = set()
        for p in pred_xyxy:
            for i, g in enumerate(gt_xyxy):
                if iou(p, g) >= IOU_THRESH:
                    matched.add(i)

        if len(gt_boxes) > 0 and len(matched) == 0:
            category, out_dir = "missed", missed_dir
        elif 0 < len(matched) < len(gt_boxes):
            category, out_dir = "partial", partial_dir
        else:
            category, out_dir = "success", success_dir

        pred_panel = draw_boxes(
            img.copy(), pred_boxes, (0,0,255),
            f"{model_name} – {category.upper()}"
        )

        combined = np.hstack([gt_panel, pred_panel])
        cv2.imwrite(
            os.path.join(out_dir, f"{name}_{model_name}_{category}.jpg"),
            combined
        )

        panels.append(pred_panel)

    # ---------- ALL MODELS ----------
    max_h = max(p.shape[0] for p in panels)
    panels = [cv2.resize(p, (p.shape[1], max_h)) for p in panels]
    all_models = np.hstack(panels)
    cv2.imwrite(os.path.join(compare_dir, f"{name}_ALL_MODELS.jpg"), all_models)

    print("Processed:", name)

print("\n✔ DONE — segmentation-safe side-by-side analysis generated")
# Out:
# Loading: YOLOv8n-S3
# Loading: YOLOv8s-S3
# Loading: YOLOv8m-S3
# Loading: YOLOv8l-S3
# Loading: YOLOv8x-S3
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 6 trashs, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000101_jpg.rf.fbf75c64095342160f45a3f55d72e725.jpg: 320x320 5 trashs, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000101_jpg.rf.fbf75c64095342160f45a3f55d72e725
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 9.4ms
# Speed: 0.5ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 12.0ms
# Speed: 1.1ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7.jpg: 320x320 2 trashs, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000152_jpg.rf.7276ef05f05dd9d3fa03c37d3467b7c7
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 2 trashs, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 1 trash, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b.jpg: 320x320 2 trashs, 20.6ms
# Speed: 1.5ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000154_jpg.rf.5ea08debfae50fb17ea33ff4ee30687b
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 3 trashs, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 4 trashs, 14.8ms
# Speed: 1.0ms preprocess, 14.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a.jpg: 320x320 5 trashs, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000154_jpg.rf.fc963f55a16242808e7e9a4a3b3d571a
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 3 trashs, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 3 trashs, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 4 trashs, 12.6ms
# Speed: 1.5ms preprocess, 12.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 5 trashs, 16.6ms
# Speed: 1.5ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1.jpg: 320x320 4 trashs, 22.3ms
# Speed: 2.2ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000182_jpg.rf.d77d8258ec020edca5f60e010b6ff0d1
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615.jpg: 320x320 1 trash, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 0001_jpg.rf.a252dea4706cc83bc1143378f6c2e615
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 3 trashs, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000225_jpg.rf.575306df948e526b06b9deff32c83059.jpg: 320x320 2 trashs, 21.6ms
# Speed: 1.5ms preprocess, 21.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000225_jpg.rf.575306df948e526b06b9deff32c83059
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 1 trash, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 1 trash, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 1 trash, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 2 trashs, 25.5ms
# Speed: 1.5ms preprocess, 25.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000256_jpg.rf.7197fb29a83207067d298d6031dc4d75.jpg: 320x320 2 trashs, 23.8ms
# Speed: 3.0ms preprocess, 23.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000256_jpg.rf.7197fb29a83207067d298d6031dc4d75
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4.jpg: 320x320 1 trash, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 0002_jpg.rf.bc3efa65dcb7b0dc5a7250303d78e6c4
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 3 trashs, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9.jpg: 320x320 5 trashs, 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000342_jpg.rf.ec8038c4caa4838f76cff4529ac65ba9
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 2 trashs, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 2 trashs, 17.2ms
# Speed: 0.0ms preprocess, 17.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0.jpg: 320x320 1 trash, 23.3ms
# Speed: 1.5ms preprocess, 23.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000356_jpg.rf.bcdff0ce7caac70e4d20f962baf1d7d0
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 2 trashs, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208.jpg: 320x320 1 trash, 23.4ms
# Speed: 1.5ms preprocess, 23.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000396_jpg.rf.8653351f0b02cf8d2757e1364e8ae208
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 (no detections), 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 (no detections), 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 (no detections), 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 1 trash, 25.2ms
# Speed: 0.4ms preprocess, 25.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace.jpg: 320x320 1 trash, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000456_jpg.rf.d05b7e4b1b53b1095d31ba0f4c632ace
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 15.7ms
# Speed: 0.4ms preprocess, 15.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 25.9ms
# Speed: 0.0ms preprocess, 25.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9.jpg: 320x320 1 trash, 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 0004_jpg.rf.9be9ac185e39d1eafb6946c534cb02c9
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000540_jpg.rf.762e4e86c895ba843747e20b6fc23345.jpg: 320x320 2 trashs, 14.0ms
# Speed: 0.5ms preprocess, 14.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000540_jpg.rf.762e4e86c895ba843747e20b6fc23345
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 (no detections), 9.1ms
# Speed: 1.5ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 1 trash, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 2 trashs, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 2 trashs, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.060a10bce6082a699235640e87da0174.jpg: 320x320 (no detections), 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000576_jpg.rf.060a10bce6082a699235640e87da0174
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 4 trashs, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 1 trash, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 2 trashs, 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7.jpg: 320x320 2 trashs, 15.3ms
# Speed: 0.0ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000576_jpg.rf.7ecaa3313beea0e0c7bbaf341cccecf7
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 12.7ms
# Speed: 0.0ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc.jpg: 320x320 5 trashs, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000577_jpg.rf.2c446ffe92fae5c1a189049871eec4dc
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 (no detections), 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 (no detections), 10.0ms
# Speed: 0.5ms preprocess, 10.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 2 trashs, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 1 trash, 15.2ms
# Speed: 0.0ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d.jpg: 320x320 3 trashs, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000592_jpg.rf.41b0aa7a9e5a8dccdef11e1e0e225c1d
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 2 trashs, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 1 trash, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698.jpg: 320x320 2 trashs, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000611_jpg.rf.7b5fd003cf94cb8308a394c8c4079698
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 9.4ms
# Speed: 0.0ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 14.7ms
# Speed: 0.6ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000634_jpg.rf.d871a3ec3983367fa6778195c8250489.jpg: 320x320 1 trash, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000634_jpg.rf.d871a3ec3983367fa6778195c8250489
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 9.8ms
# Speed: 0.3ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 2 trashs, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 11.6ms
# Speed: 0.5ms preprocess, 11.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 3 trashs, 14.3ms
# Speed: 1.5ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab.jpg: 320x320 1 trash, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000659_jpg.rf.41c5418a54b9f30aed9cb734d7e6e9ab
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 1 trash, 9.3ms
# Speed: 1.0ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 1 trash, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 1 trash, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 1 trash, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c.jpg: 320x320 2 trashs, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000667_jpg.rf.3d378b2fb67b910b7e10911495fd743c
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 1 trash, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 (no detections), 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 1 trash, 12.3ms
# Speed: 1.4ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 (no detections), 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000703_jpg.rf.d65d131b73063d4422d327439bc1307e.jpg: 320x320 1 trash, 13.8ms
# Speed: 1.5ms preprocess, 13.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000703_jpg.rf.d65d131b73063d4422d327439bc1307e
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 2 trashs, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 5 trashs, 9.9ms
# Speed: 0.0ms preprocess, 9.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 4 trashs, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 3 trashs, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea.jpg: 320x320 4 trashs, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000740_jpg.rf.63ae0c52ec791c7ab2c4d1ab5ea684ea
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29.jpg: 320x320 1 trash, 20.0ms
# Speed: 1.5ms preprocess, 20.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000799_jpg.rf.af5d2dc4f5609b9ffb2d63b488aedc29
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 12.1ms
# Speed: 1.8ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 15.0ms
# Speed: 1.1ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0.jpg: 320x320 2 trashs, 20.2ms
# Speed: 1.5ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000906_jpg.rf.2d7e211326f14ff123a06eee7b5d4ff0
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 7.6ms
# Speed: 1.1ms preprocess, 7.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 11.8ms
# Speed: 1.5ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 15.9ms
# Speed: 0.0ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000976_jpg.rf.6b95ae0567e3900153cd9067b377d044.jpg: 320x320 1 trash, 22.6ms
# Speed: 1.5ms preprocess, 22.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000976_jpg.rf.6b95ae0567e3900153cd9067b377d044
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2.jpg: 320x320 (no detections), 23.0ms
# Speed: 1.5ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 000990_jpg.rf.e0b5bcd0768c70a0aab7850f402d4db2
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 3 trashs, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 2 trashs, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 2 trashs, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 2 trashs, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e.jpg: 320x320 4 trashs, 22.4ms
# Speed: 1.5ms preprocess, 22.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 001004_jpg.rf.436f934ecfdc1b4b4c4e709f27c36f6e
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 4 trashs, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 2 trashs, 9.7ms
# Speed: 0.4ms preprocess, 9.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 2 trashs, 13.3ms
# Speed: 0.0ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 4 trashs, 15.8ms
# Speed: 4.7ms preprocess, 15.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001014_jpg.rf.100438206cb025644fb2b4a260661713.jpg: 320x320 3 trashs, 21.5ms
# Speed: 2.3ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 001014_jpg.rf.100438206cb025644fb2b4a260661713
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 (no detections), 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 26.0ms
# Speed: 0.0ms preprocess, 26.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b.jpg: 320x320 1 trash, 37.9ms
# Speed: 0.0ms preprocess, 37.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 001030_jpg.rf.5fb826ff1c417fc49aa0b725e894a14b
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 12.2ms
# Speed: 0.8ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001056_jpg.rf.582c750d50c34020f112512569261032.jpg: 320x320 2 trashs, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 001056_jpg.rf.582c750d50c34020f112512569261032
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a.jpg: 320x320 2 trashs, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 001059_jpg.rf.3d9f7f87cf39a16a57d3f2e41c87de4a
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 9.3ms
# Speed: 0.7ms preprocess, 9.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0.jpg: 320x320 1 trash, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 320)
# Processed: 0010_jpg.rf.9dc6c04f23c45319eed1c2257bb9f6a0
#
# ...
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2330_jpg.rf.60b017fce164142dead412891dd997fc.jpg: 192x320 1 trash, 28.5ms
# Speed: 1.5ms preprocess, 28.5ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2330_jpg.rf.60b017fce164142dead412891dd997fc
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 16.3ms
# Speed: 0.0ms preprocess, 16.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd.jpg: 192x320 1 trash, 29.3ms
# Speed: 2.2ms preprocess, 29.3ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2333_jpg.rf.3ab62c93fe155ebff593285cd373aadd
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 16.8ms
# Speed: 0.9ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 22.7ms
# Speed: 1.6ms preprocess, 22.7ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b.jpg: 192x320 3 trashs, 29.2ms
# Speed: 1.0ms preprocess, 29.2ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2340_jpg.rf.5ddf4cdced3925d0d7afd1c74eaf8c0b
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 16.4ms
# Speed: 1.5ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 23.4ms
# Speed: 0.4ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c.jpg: 192x320 (no detections), 27.9ms
# Speed: 2.0ms preprocess, 27.9ms inference, 2.9ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2353_jpg.rf.c026c80a264888874a0c0873eb744b7c
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 14.9ms
# Speed: 1.5ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a.jpg: 192x320 1 trash, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2356_jpg.rf.b4cb14a88fca4d08d5938cab9fc5ca1a
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 14.4ms
# Speed: 1.5ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 22.9ms
# Speed: 0.7ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48.jpg: 192x320 (no detections), 30.1ms
# Speed: 0.0ms preprocess, 30.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2366_jpg.rf.e85cbc13f5291dd16dd62169734b7f48
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 1 trash, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 1 trash, 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 15.4ms
# Speed: 0.0ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 24.4ms
# Speed: 0.0ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5.jpg: 192x320 (no detections), 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2370_jpg.rf.ad5b60a8cef099c877396a1c20fc83c5
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 12.7ms
# Speed: 1.5ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 14.4ms
# Speed: 0.4ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 23.2ms
# Speed: 0.0ms preprocess, 23.2ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3.jpg: 192x320 1 trash, 28.3ms
# Speed: 1.5ms preprocess, 28.3ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2374_jpg.rf.cc7908ae463bc936f112e6c10f3b44a3
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 17.7ms
# Speed: 0.0ms preprocess, 17.7ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 24.0ms
# Speed: 0.8ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c.jpg: 192x320 (no detections), 30.4ms
# Speed: 0.0ms preprocess, 30.4ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2387_jpg.rf.ca676a2e378d40cb0e55b1a21e18023c
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 (no detections), 13.0ms
# Speed: 1.2ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 (no detections), 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 (no detections), 14.7ms
# Speed: 0.5ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 23.9ms
# Speed: 1.7ms preprocess, 23.9ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b.jpg: 192x320 1 trash, 28.1ms
# Speed: 1.6ms preprocess, 28.1ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_2_2619_jpg.rf.db2cf3a6cd8fd1763e78152bbddeaa2b
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 1.8ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 3 trashs, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 22.9ms
# Speed: 0.0ms preprocess, 22.9ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b.jpg: 192x320 4 trashs, 29.3ms
# Speed: 1.3ms preprocess, 29.3ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_3_0334_jpg.rf.3a3fdd458120c288c7f04299b0c8616b
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 1 trash, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 3.1ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 (no detections), 16.1ms
# Speed: 1.5ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 1 trash, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 (no detections), 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# image 1/1 C:\Users\User\Documents\Rabab\dataset\Scenario 3\reflection\test_glare_fixed\scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d.jpg: 192x320 (no detections), 29.6ms
# Speed: 1.5ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 320)
# Processed: scene_3_1834_jpg.rf.161b9f7c4ea207f763463383be4e373d
#
# ✔ DONE — segmentation-safe side-by-side analysis generated
